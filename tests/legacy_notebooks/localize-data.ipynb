# %%
# %load_ext autoreload
# %autoreload 2

# %%
from isce2_topsapp import (
    download_slcs,
    download_orbits,
    download_dem_for_isce2,
    download_aux_cal,
)
# Out:
# Using default ISCE Path: /Users/cmarshak/miniforge3/envs/topsapp_env/lib/python3.11/site-packages/isce
# /Users/cmarshak/miniforge3/envs/topsapp_env/lib/python3.11/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Input Data

# %%
data = {
    "reference_scenes": [
        "S1B_IW_SLC__1SDV_20210723T014947_20210723T015014_027915_0354B4_B3A9"
    ],
    "secondary_scenes": [
        "S1B_IW_SLC__1SDV_20210711T014922_20210711T014949_027740_034F80_859D",
        "S1B_IW_SLC__1SDV_20210711T014947_20210711T015013_027740_034F80_D404",
        "S1B_IW_SLC__1SDV_20210711T015011_20210711T015038_027740_034F80_376C",
    ],
}
reference_scenes = data["reference_scenes"]
secondary_scenes = data["secondary_scenes"]

# %%
dry_run = True

# %% [markdown]
# # SLC

# %% [markdown]
# Do everything but download SLCs
# *Note, if you encounter `NetrcParseError: access too permissive` error, try to update permissions with `chmod 0600 ~/.netrc`

# %%
out_slc = download_slcs(reference_scenes, secondary_scenes, dry_run=dry_run)
out_slc
# Out:
# Downloading SLCs: 100%|█| 4/4 [00:02<00:00,  1.3
# {'ref_paths': ['S1B_IW_SLC__1SDV_20210723T014947_20210723T015014_027915_0354B4_B3A9.zip'],
#  'sec_paths': ['S1B_IW_SLC__1SDV_20210711T015011_20210711T015038_027740_034F80_376C.zip',
#   'S1B_IW_SLC__1SDV_20210711T014947_20210711T015013_027740_034F80_D404.zip',
#   'S1B_IW_SLC__1SDV_20210711T014922_20210711T014949_027740_034F80_859D.zip'],
#  'extent': [-119.080994, 33.405682, -115.988029, 35.43090952856198],
#  'gunw_geo': <POLYGON ((-118.731 33.534, -119.051 34.9, -119.051 34.9, -119.052 34.903, -...>,
#  'processing_extent': [-119.080994, 33.405682, -115.988029, 35.43090952856198],
#  'reference_properties': [{'centerLat': 34.4266,
#    'centerLon': -117.5237,
#    'stopTime': '2021-07-23T01:50:14Z',
#    'fileID': 'S1B_IW_SLC__1SDV_20210723T014947_20210723T015014_027915_0354B4_B3A9-SLC',
#    'flightDirection': 'ASCENDING',
#    'pathNumber': 64,
#    'processingLevel': 'SLC',
#    'url': 'https://datapool.asf.alaska.edu/SLC/SB/S1B_IW_SLC__1SDV_20210723T014947_20210723T015014_027915_0354B4_B3A9.zip',
#    'startTime': '2021-07-23T01:49:47Z',
#    'sceneName': 'S1B_IW_SLC__1SDV_20210723T014947_20210723T015014_027915_0354B4_B3A9',
#    'browse': None,
#    'platform': 'Sentinel-1B',
#    'bytes': 4334545363,
#    'md5sum': 'fac5678b4b27b4321cde8953a95d0416',
#    'frameNumber': 108,
#    'granuleType': 'SENTINEL_1B_FRAME',
#    'orbit': 27915,
#    'polarization': 'VV+VH',
#    'processingDate': '2021-07-23T01:49:47Z',
#    'sensor': 'C-SAR',
#    'groupID': 'S1B_IWDV_0107_0114_027915_064',
#    'pgeVersion': '003.31',
#    'fileName': 'S1B_IW_SLC__1SDV_20210723T014947_20210723T015014_027915_0354B4_B3A9.zip',
#    'beamModeType': 'IW',
#    's3Urls': ['s3://asf-ngap2w-p-s1-slc-7b420b89/S1B_IW_SLC__1SDV_20210723T014947_20210723T015014_027915_0354B4_B3A9.zip']}],
#  'secondary_properties': [{'centerLat': 35.9201,
#    'centerLon': -117.85,
#    'stopTime': '2021-07-11T01:50:38Z',
#    'fileID': 'S1B_IW_SLC__1SDV_20210711T015011_20210711T015038_027740_034F80_376C-SLC',
#    'flightDirection': 'ASCENDING',
#    'pathNumber': 64,
#    'processingLevel': 'SLC',
#    'url': 'https://datapool.asf.alaska.edu/SLC/SB/S1B_IW_SLC__1SDV_20210711T015011_20210711T015038_027740_034F80_376C.zip',
#    'startTime': '2021-07-11T01:50:11Z',
#    'sceneName': 'S1B_IW_SLC__1SDV_20210711T015011_20210711T015038_027740_034F80_376C',
#    'browse': None,
#    'platform': 'Sentinel-1B',
#    'bytes': 4435118066,
#    'md5sum': '53c785599671f23bebc9493e7c5113c4',
#    'frameNumber': 113,
#    'granuleType': 'SENTINEL_1B_FRAME',
#    'orbit': 27740,
#    'polarization': 'VV+VH',
#    'processingDate': '2021-07-11T01:50:11Z',
#    'sensor': 'C-SAR',
#    'groupID': 'S1B_IWDV_0112_0119_027740_064',
#    'pgeVersion': '003.31',
#    'fileName': 'S1B_IW_SLC__1SDV_20210711T015011_20210711T015038_027740_034F80_376C.zip',
#    'beamModeType': 'IW',
#    's3Urls': ['s3://asf-ngap2w-p-s1-slc-7b420b89/S1B_IW_SLC__1SDV_20210711T015011_20210711T015038_027740_034F80_376C.zip']},
#   {'centerLat': 34.4262,
#    'centerLon': -117.5234,
#    'stopTime': '2021-07-11T01:50:13Z',
#    'fileID': 'S1B_IW_SLC__1SDV_20210711T014947_20210711T015013_027740_034F80_D404-SLC',
#    'flightDirection': 'ASCENDING',
#    'pathNumber': 64,
#    'processingLevel': 'SLC',
#    'url': 'https://datapool.asf.alaska.edu/SLC/SB/S1B_IW_SLC__1SDV_20210711T014947_20210711T015013_027740_034F80_D404.zip',
#    'startTime': '2021-07-11T01:49:47Z',
#    'sceneName': 'S1B_IW_SLC__1SDV_20210711T014947_20210711T015013_027740_034F80_D404',
#    'browse': None,
#    'platform': 'Sentinel-1B',
#    'bytes': 4345308811,
#    'md5sum': '56b2004a93ad86b82e128e5ac9f04a94',
#    'frameNumber': 108,
#    'granuleType': 'SENTINEL_1B_FRAME',
#    'orbit': 27740,
#    'polarization': 'VV+VH',
#    'processingDate': '2021-07-11T01:49:47Z',
#    'sensor': 'C-SAR',
#    'groupID': 'S1B_IWDV_0107_0114_027740_064',
#    'pgeVersion': '003.31',
#    'fileName': 'S1B_IW_SLC__1SDV_20210711T014947_20210711T015013_027740_034F80_D404.zip',
#    'beamModeType': 'IW',
#    's3Urls': ['s3://asf-ngap2w-p-s1-slc-7b420b89/S1B_IW_SLC__1SDV_20210711T014947_20210711T015013_027740_034F80_D404.zip']},
#   {'centerLat': 32.9309,
#    'centerLon': -117.2057,
#    'stopTime': '2021-07-11T01:49:49Z',
#    'fileID': 'S1B_IW_SLC__1SDV_20210711T014922_20210711T014949_027740_034F80_859D-SLC',
#    'flightDirection': 'ASCENDING',
#    'pathNumber': 64,
#    'processingLevel': 'SLC',
#    'url': 'https://datapool.asf.alaska.edu/SLC/SB/S1B_IW_SLC__1SDV_20210711T014922_20210711T014949_027740_034F80_859D.zip',
#    'startTime': '2021-07-11T01:49:22Z',
#    'sceneName': 'S1B_IW_SLC__1SDV_20210711T014922_20210711T014949_027740_034F80_859D',
#    'browse': None,
#    'platform': 'Sentinel-1B',
#    'bytes': 4150793626,
#    'md5sum': '8cad65891ffcbb32218cece857104ed3',
#    'frameNumber': 103,
#    'granuleType': 'SENTINEL_1B_FRAME',
#    'orbit': 27740,
#    'polarization': 'VV+VH',
#    'processingDate': '2021-07-11T01:49:22Z',
#    'sensor': 'C-SAR',
#    'groupID': 'S1B_IWDV_0102_0109_027740_064',
#    'pgeVersion': '003.31',
#    'fileName': 'S1B_IW_SLC__1SDV_20210711T014922_20210711T014949_027740_034F80_859D.zip',
#    'beamModeType': 'IW',
#    's3Urls': ['s3://asf-ngap2w-p-s1-slc-7b420b89/S1B_IW_SLC__1SDV_20210711T014922_20210711T014949_027740_034F80_859D.zip']}]}

# %% [markdown]
# # Orbits

# %%
out_orbit = download_orbits(reference_scenes, secondary_scenes)
out_orbit
# Out:
# {'orbit_directory': 'orbits',
#  'reference_orbits': ['orbits/S1B_OPER_AUX_POEORB_OPOD_20210812T111941_V20210722T225942_20210724T005942.EOF'],
#  'secondary_orbits': ['orbits/S1B_OPER_AUX_POEORB_OPOD_20210731T111940_V20210710T225942_20210712T005942.EOF']}

# %% [markdown]
# # DEM
#
# Don't currently have "dry-run" for this localization.

# %%
out_dem = download_dem_for_isce2(out_slc["extent"])
out_dem
# Out:
# Opening glo_30 Datasets: 100%|█| 15/15 [00:27<00
# Reading tile metadata: 100%|█| 15/15 [00:00<00:0
# Reading tile imagery: 100%|█| 15/15 [00:46<00:00
# 2025-09-17 13:49:26,782 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/us_nga_egm2008_1_4326__agisoft.tif.aux.xml: 403
# 2025-09-17 13:49:26,846 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/us_nga_egm2008_1_4326__agisoft.aux: 403
# 2025-09-17 13:49:26,908 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/us_nga_egm2008_1_4326__agisoft.AUX: 403
# 2025-09-17 13:49:26,965 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/us_nga_egm2008_1_4326__agisoft.tif.aux: 403
# 2025-09-17 13:49:27,022 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/us_nga_egm2008_1_4326__agisoft.tif.AUX: 403
# 2025-09-17 13:49:27,084 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/us_nga_egm2008_1_4326__agisoft.xml: 403
# 2025-09-17 13:49:27,142 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/us_nga_egm2008_1_4326__agisoft.XML: 403
# 2025-09-17 13:49:27,273 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/us_nga_egm2008_1_4326__agisoft.aux: 403
# 2025-09-17 13:49:27,337 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/us_nga_egm2008_1_4326__agisoft.AUX: 403
# 2025-09-17 13:49:27,402 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/us_nga_egm2008_1_4326__agisoft.tif.aux: 403
# 2025-09-17 13:49:27,466 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/us_nga_egm2008_1_4326__agisoft.tif.AUX: 403
# 2025-09-17 13:49:27,529 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/us_nga_egm2008_1_4326__agisoft.tif.msk: 403
# 2025-09-17 13:49:27,586 - rasterio._env - WARNING - CPLE_AppDefined in HTTP response code on https://aria-geoid.s3.us-west-2.amazonaws.com/us_nga_egm2008_1_4326__agisoft.tif.MSK: 403
# fixing xml file path for file: low_res.dem.wgs84
# Writing geotrans to VRT for /Users/cmarshak/bekaert-team/DockerizedTopsApp/tests/low_res.dem.wgs84
# fixing xml file path for file: full_res.dem.wgs84
# Writing geotrans to VRT for /Users/cmarshak/bekaert-team/DockerizedTopsApp/tests/full_res.dem.wgs84
# {'extent_buffered': [-120.0, 33.0, -115.0, 36.0],
#  'full_res_dem_path': PosixPath('full_res.dem.wgs84'),
#  'low_res_dem_path': PosixPath('low_res.dem.wgs84')}

# %% [markdown]
# # Aux Cal

# %%
out_aux_cal = download_aux_cal()

# %% [markdown]
# # Combining Metadata

# %%
out = {**out_slc, **out_dem, **out_aux_cal, **out_orbit}
out
# Out:
# {'ref_paths': ['S1B_IW_SLC__1SDV_20210723T014947_20210723T015014_027915_0354B4_B3A9.zip'],
#  'sec_paths': ['S1B_IW_SLC__1SDV_20210711T015011_20210711T015038_027740_034F80_376C.zip',
#   'S1B_IW_SLC__1SDV_20210711T014947_20210711T015013_027740_034F80_D404.zip',
#   'S1B_IW_SLC__1SDV_20210711T014922_20210711T014949_027740_034F80_859D.zip'],
#  'extent': [-119.080994, 33.405682, -115.988029, 35.43090952856198],
#  'gunw_geo': <POLYGON ((-118.731 33.534, -119.051 34.9, -119.051 34.9, -119.052 34.903, -...>,
#  'processing_extent': [-119.080994, 33.405682, -115.988029, 35.43090952856198],
#  'reference_properties': [{'centerLat': 34.4266,
#    'centerLon': -117.5237,
#    'stopTime': '2021-07-23T01:50:14Z',
#    'fileID': 'S1B_IW_SLC__1SDV_20210723T014947_20210723T015014_027915_0354B4_B3A9-SLC',
#    'flightDirection': 'ASCENDING',
#    'pathNumber': 64,
#    'processingLevel': 'SLC',
#    'url': 'https://datapool.asf.alaska.edu/SLC/SB/S1B_IW_SLC__1SDV_20210723T014947_20210723T015014_027915_0354B4_B3A9.zip',
#    'startTime': '2021-07-23T01:49:47Z',
#    'sceneName': 'S1B_IW_SLC__1SDV_20210723T014947_20210723T015014_027915_0354B4_B3A9',
#    'browse': None,
#    'platform': 'Sentinel-1B',
#    'bytes': 4334545363,
#    'md5sum': 'fac5678b4b27b4321cde8953a95d0416',
#    'frameNumber': 108,
#    'granuleType': 'SENTINEL_1B_FRAME',
#    'orbit': 27915,
#    'polarization': 'VV+VH',
#    'processingDate': '2021-07-23T01:49:47Z',
#    'sensor': 'C-SAR',
#    'groupID': 'S1B_IWDV_0107_0114_027915_064',
#    'pgeVersion': '003.31',
#    'fileName': 'S1B_IW_SLC__1SDV_20210723T014947_20210723T015014_027915_0354B4_B3A9.zip',
#    'beamModeType': 'IW',
#    's3Urls': ['s3://asf-ngap2w-p-s1-slc-7b420b89/S1B_IW_SLC__1SDV_20210723T014947_20210723T015014_027915_0354B4_B3A9.zip']}],
#  'secondary_properties': [{'centerLat': 35.9201,
#    'centerLon': -117.85,
#    'stopTime': '2021-07-11T01:50:38Z',
#    'fileID': 'S1B_IW_SLC__1SDV_20210711T015011_20210711T015038_027740_034F80_376C-SLC',
#    'flightDirection': 'ASCENDING',
#    'pathNumber': 64,
#    'processingLevel': 'SLC',
#    'url': 'https://datapool.asf.alaska.edu/SLC/SB/S1B_IW_SLC__1SDV_20210711T015011_20210711T015038_027740_034F80_376C.zip',
#    'startTime': '2021-07-11T01:50:11Z',
#    'sceneName': 'S1B_IW_SLC__1SDV_20210711T015011_20210711T015038_027740_034F80_376C',
#    'browse': None,
#    'platform': 'Sentinel-1B',
#    'bytes': 4435118066,
#    'md5sum': '53c785599671f23bebc9493e7c5113c4',
#    'frameNumber': 113,
#    'granuleType': 'SENTINEL_1B_FRAME',
#    'orbit': 27740,
#    'polarization': 'VV+VH',
#    'processingDate': '2021-07-11T01:50:11Z',
#    'sensor': 'C-SAR',
#    'groupID': 'S1B_IWDV_0112_0119_027740_064',
#    'pgeVersion': '003.31',
#    'fileName': 'S1B_IW_SLC__1SDV_20210711T015011_20210711T015038_027740_034F80_376C.zip',
#    'beamModeType': 'IW',
#    's3Urls': ['s3://asf-ngap2w-p-s1-slc-7b420b89/S1B_IW_SLC__1SDV_20210711T015011_20210711T015038_027740_034F80_376C.zip']},
#   {'centerLat': 34.4262,
#    'centerLon': -117.5234,
#    'stopTime': '2021-07-11T01:50:13Z',
#    'fileID': 'S1B_IW_SLC__1SDV_20210711T014947_20210711T015013_027740_034F80_D404-SLC',
#    'flightDirection': 'ASCENDING',
#    'pathNumber': 64,
#    'processingLevel': 'SLC',
#    'url': 'https://datapool.asf.alaska.edu/SLC/SB/S1B_IW_SLC__1SDV_20210711T014947_20210711T015013_027740_034F80_D404.zip',
#    'startTime': '2021-07-11T01:49:47Z',
#    'sceneName': 'S1B_IW_SLC__1SDV_20210711T014947_20210711T015013_027740_034F80_D404',
#    'browse': None,
#    'platform': 'Sentinel-1B',
#    'bytes': 4345308811,
#    'md5sum': '56b2004a93ad86b82e128e5ac9f04a94',
#    'frameNumber': 108,
#    'granuleType': 'SENTINEL_1B_FRAME',
#    'orbit': 27740,
#    'polarization': 'VV+VH',
#    'processingDate': '2021-07-11T01:49:47Z',
#    'sensor': 'C-SAR',
#    'groupID': 'S1B_IWDV_0107_0114_027740_064',
#    'pgeVersion': '003.31',
#    'fileName': 'S1B_IW_SLC__1SDV_20210711T014947_20210711T015013_027740_034F80_D404.zip',
#    'beamModeType': 'IW',
#    's3Urls': ['s3://asf-ngap2w-p-s1-slc-7b420b89/S1B_IW_SLC__1SDV_20210711T014947_20210711T015013_027740_034F80_D404.zip']},
#   {'centerLat': 32.9309,
#    'centerLon': -117.2057,
#    'stopTime': '2021-07-11T01:49:49Z',
#    'fileID': 'S1B_IW_SLC__1SDV_20210711T014922_20210711T014949_027740_034F80_859D-SLC',
#    'flightDirection': 'ASCENDING',
#    'pathNumber': 64,
#    'processingLevel': 'SLC',
#    'url': 'https://datapool.asf.alaska.edu/SLC/SB/S1B_IW_SLC__1SDV_20210711T014922_20210711T014949_027740_034F80_859D.zip',
#    'startTime': '2021-07-11T01:49:22Z',
#    'sceneName': 'S1B_IW_SLC__1SDV_20210711T014922_20210711T014949_027740_034F80_859D',
#    'browse': None,
#    'platform': 'Sentinel-1B',
#    'bytes': 4150793626,
#    'md5sum': '8cad65891ffcbb32218cece857104ed3',
#    'frameNumber': 103,
#    'granuleType': 'SENTINEL_1B_FRAME',
#    'orbit': 27740,
#    'polarization': 'VV+VH',
#    'processingDate': '2021-07-11T01:49:22Z',
#    'sensor': 'C-SAR',
#    'groupID': 'S1B_IWDV_0102_0109_027740_064',
#    'pgeVersion': '003.31',
#    'fileName': 'S1B_IW_SLC__1SDV_20210711T014922_20210711T014949_027740_034F80_859D.zip',
#    'beamModeType': 'IW',
#    's3Urls': ['s3://asf-ngap2w-p-s1-slc-7b420b89/S1B_IW_SLC__1SDV_20210711T014922_20210711T014949_027740_034F80_859D.zip']}],
#  'extent_buffered': [-120.0, 33.0, -115.0, 36.0],
#  'full_res_dem_path': PosixPath('full_res.dem.wgs84'),
#  'low_res_dem_path': PosixPath('low_res.dem.wgs84'),
#  'aux_cal_dir': 'aux_cal',
#  'orbit_directory': 'orbits',
#  'reference_orbits': ['orbits/S1B_OPER_AUX_POEORB_OPOD_20210812T111941_V20210722T225942_20210724T005942.EOF'],
#  'secondary_orbits': ['orbits/S1B_OPER_AUX_POEORB_OPOD_20210731T111940_V20210710T225942_20210712T005942.EOF']}

# %% [markdown]
# # Check Name

# %%
from isce2_topsapp.packaging import get_gunw_id

gunw_id = get_gunw_id(
    reference_properties=out["reference_properties"],
    secondary_properties=out["secondary_properties"],
    extent=out["extent"],
)
gunw_id
# Out:
# 'S1-GUNW-A-R-064-tops-20210723_20210711-015000-00119W_00033N-PP-6267-v3_0_1'
