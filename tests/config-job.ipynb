# %%
# %load_ext autoreload
# %autoreload 2

# %%
from isce2_topsapp.enumeration import config_job
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce

# %%
# Find frame
frame_id = 9848
reference_date = '2015-05-02'
secondary_date= '2015-05-26'

# %%
# Confirm existence of the ARIA GUNW-S1, skip to avoid pytest failing
#config_job.get_job_config(frame_id, reference_date, secondary_date)
# Out:
# Frame 9848: Number of dropped dates 4: ['2014-12-21', '2015-01-14', '2015-02-07', '2017-01-21']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Confirm existence of the ARIA GUNW-S1
# ----> 2 config_job.get_job_config(frame_id, reference_date, secondary_date)
#
# File /u/aurora-r0/govorcin/02_ACCESS/DockerizedTopsApp/isce2_topsapp/enumeration/config_job.py:74, in get_job_config(frame_id, reference_date, secondary_date)
#      72 if len(aria_s1_hits) > 0:
#      73     filename = aria_s1_hits.data[0].properties["fileName"]
# ---> 74     raise ValueError(
#      75         f"GUNW exists: {filename}!\nSkip generation of topsApp job config."
#      76     )
#      77 return output
#
# ValueError: GUNW exists: S1-GUNW-A-R-064-tops-20150526_20150502-015001-00119W_00033N-PP-f4e8-v3_0_1.nc!
# Skip generation of topsApp job config.

# %%
# Find frame
frame_id = 9848
reference_date = '2015-05-02'
secondary_date= '2025-05-09'

# %%
# Confirm existence of the ARIA GUNW-S1
config_job.get_job_config(frame_id, reference_date, secondary_date)
# Out:
# Frame 9848: Number of dropped dates 4: ['2014-12-21', '2015-01-14', '2015-02-07', '2017-01-21']
# 2025-05-02 00:00:00+00:00 2025-05-09 00:00:00+00:00
# {'reference': ['S1A_IW_SLC__1SDV_20250509T015010_20250509T015040_059111_07557C_C6AD',
#   'S1A_IW_SLC__1SDV_20250509T015038_20250509T015105_059111_07557C_191F'],
#  'secondary': ['S1C_IW_SLC__1SDV_20250503T014857_20250503T014924_002160_004961_E4B4',
#   'S1C_IW_SLC__1SDV_20250503T014922_20250503T014949_002160_004961_D210'],
#  'reference_date': '2025-05-09',
#  'secondary_date': '2025-05-02',
#  'frame_id': 9848,
#  'geometry': 'POLYGON ((-118.7422839814056 33.522019425069004, -118.70857849744431 33.37655247268019, -115.95419416339799 33.37655247268019, -116.1484651706841 34.350017036158924, -116.146971 34.350215, -116.18518612531783 34.54110609799962, -118.97625750551008 34.54110609799962, -118.8581614159091 34.03642974083342, -118.861808 34.035838, -118.7422839814056 33.522019425069004))'}
